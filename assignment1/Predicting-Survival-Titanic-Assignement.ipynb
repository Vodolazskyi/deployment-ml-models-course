# %% [markdown]
# ## Predicting Survival on the Titanic
#
# ### History
# Perhaps one of the most infamous shipwrecks in history, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 people on board. Interestingly, by analysing the probability of survival based on few attributes like gender, age, and social status, we can make very accurate predictions on which passengers would survive. Some groups of people were more likely to survive than others, such as women, children, and the upper-class. Therefore, we can learn about the society priorities and privileges at the time.
#
# ### Assignment:
#
# Build a Machine Learning Pipeline, to engineer the features in the data set and predict who is more likely to Survive the catastrophe.
#
# Follow the Jupyter notebook below, and complete the missing bits of code, to achieve each one of the pipeline steps.

# %%
import re

# to handle datasets
import pandas as pd
import numpy as np

# for visualization
import matplotlib.pyplot as plt

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler

# to build the models
from sklearn.linear_model import LogisticRegression

# to evaluate the models
from sklearn.metrics import accuracy_score, roc_auc_score

# to persist the model and the scaler
import joblib

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# ## Prepare the data set

# %%
# load the data - it is available open source and online

data = pd.read_csv('https://www.openml.org/data/get_csv/16826755/phpMYEkMl')

# display data
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# replace interrogation marks by NaN values

data = data.replace('?', np.nan)

# %%
# retain only the first cabin if more than
# 1 are available per passenger

def get_first_cabin(row):
    try:
        return row.split()[0]
    except:
        return np.nan
    
data['cabin'] = data['cabin'].apply(get_first_cabin)

# %%
# extracts the title (Mr, Ms, etc) from the name variable

def get_title(passenger):
    line = passenger
    if re.search('Mrs', line):
        return 'Mrs'
    elif re.search('Mr', line):
        return 'Mr'
    elif re.search('Miss', line):
        return 'Miss'
    elif re.search('Master', line):
        return 'Master'
    else:
        return 'Other'
    
data['title'] = data['name'].apply(get_title)

# %%
# cast numerical variables as floats

data['fare'] = data['fare'].astype('float')
data['age'] = data['age'].astype('float')

# %%
# drop unnecessary variables

data.drop(labels=['name','ticket', 'boat', 'body','home.dest'], axis=1, inplace=True)

# display data
data.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare cabin embarked  \
# 0       1         1  female  29.0000      0      0  211.3375    B5        S
# 1       1         1    male   0.9167      1      2  151.5500   C22        S
# 2       1         0  female   2.0000      1      2  151.5500   C22        S
# 3       1         0    male  30.0000      1      2  151.5500   C22        S
# 4       1         0  female  25.0000      1      2  151.5500   C22        S
#
#     title
# 0    Miss
# 1  Master
# 2    Miss
# 3      Mr
# 4     Mrs

# %%
# save the data set

data.to_csv('titanic.csv', index=False)

# %% [markdown]
# ## Data Exploration
#
# ### Find numerical and categorical variables

# %%
target = 'survived'

# %%
vars_num = [col for col in data.columns if data[col].dtype != 'O' and col != target]

vars_cat = [col for col in data.columns if data[col].dtype == 'O']

print('Number of numerical variables: {}'.format(len(vars_num)))
print('Number of categorical variables: {}'.format(len(vars_cat)))
# Out:
# Number of numerical variables: 5
# Number of categorical variables: 4

# %% [markdown]
# ### Find missing values in variables

# %%
# first in numerical variables
for col in vars_num:
    if data[col].isna().sum():
        print('{} column has {:.2f}% of missing values'.format(col, data[col].isna().sum() / len(data) * 100))
# Out:
# age column has 20.09% of missing values
# fare column has 0.08% of missing values

# %%
# now in categorical variables
for col in vars_cat:
    if data[col].isna().sum():
        print('{} column has {:.2f}% of missing values'.format(col, data[col].isna().sum() / len(data) * 100))
# Out:
# cabin column has 77.46% of missing values
# embarked column has 0.15% of missing values

# %% [markdown]
# ### Determine cardinality of categorical variables

# %%
data[vars_cat].nunique()
# Out:
# sex           2
# cabin       181
# embarked      3
# title         5
# dtype: int64

# %% [markdown]
# ### Determine the distribution of numerical variables

# %%
def plot_hist(df, col):
    df[col].hist()
    plt.title(col)
    plt.show()

for col in vars_num:
    plot_hist(data, col)

# %% [markdown]
# ## Separate data into train and test
#
# Use the code below for reproducibility. Don't change it.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop('survived', axis=1),  # predictors
    data['survived'],  # target
    test_size=0.2,  # percentage of obs in test set
    random_state=0)  # seed to ensure reproducibility

X_train.shape, X_test.shape
# Out:
# ((1047, 9), (262, 9))

# %% [markdown]
# ## Feature Engineering
#
# ### Extract only the letter (and drop the number) from the variable Cabin

# %%
def get_first_letter(text):
    try:
        return text[0]
    except:
        return text

# %%
X_train['cabin'] = X_train['cabin'].apply(lambda x: get_first_letter(x))
X_test['cabin'] = X_test['cabin'].apply(lambda x: get_first_letter(x))
X_test
# Out:
#       pclass     sex   age  sibsp  parch     fare cabin embarked title
# 1139       3    male  38.0      0      0   7.8958   NaN        S    Mr
# 533        2  female  21.0      0      1  21.0000   NaN        S  Miss
# 459        2    male  42.0      1      0  27.0000   NaN        S    Mr
# 1150       3    male   NaN      0      0  14.5000   NaN        S    Mr
# 393        2    male  25.0      0      0  31.5000   NaN        S    Mr
# ...      ...     ...   ...    ...    ...      ...   ...      ...   ...
# 753        3    male  22.0      0      0   8.0500   NaN        S    Mr
# 1052       3    male   NaN      0      0   7.8958   NaN        S    Mr
# 426        2    male  30.0      0      0  13.0000   NaN        S    Mr
# 554        2    male  26.0      0      0  13.0000   NaN        S    Mr
# 1213       3    male   NaN      0      0   8.0500   NaN        S    Mr
#
# [262 rows x 9 columns]

# %% [markdown]
# ### Fill in Missing data in numerical variables:
#
# - Add a binary missing indicator
# - Fill NA in original variable with the median

# %%
for col in vars_num:
    median_val = X_train[col].median()
    X_train[col+'_is_na'] = np.where(X_train[col].isna(), 1, 0)
    X_train[col] = X_train[col].fillna(median_val)
    X_test[col+'_is_na'] = np.where(X_test[col].isna(), 1, 0)
    X_test[col] = X_test[col].fillna(median_val)    
X_test
# Out:
#       pclass     sex   age  sibsp  parch     fare cabin embarked title  \
# 1139       3    male  38.0      0      0   7.8958   NaN        S    Mr
# 533        2  female  21.0      0      1  21.0000   NaN        S  Miss
# 459        2    male  42.0      1      0  27.0000   NaN        S    Mr
# 1150       3    male  28.0      0      0  14.5000   NaN        S    Mr
# 393        2    male  25.0      0      0  31.5000   NaN        S    Mr
# ...      ...     ...   ...    ...    ...      ...   ...      ...   ...
# 753        3    male  22.0      0      0   8.0500   NaN        S    Mr
# 1052       3    male  28.0      0      0   7.8958   NaN        S    Mr
# 426        2    male  30.0      0      0  13.0000   NaN        S    Mr
# 554        2    male  26.0      0      0  13.0000   NaN        S    Mr
# 1213       3    male  28.0      0      0   8.0500   NaN        S    Mr
#
#       pclass_is_na  age_is_na  sibsp_is_na  parch_is_na  fare_is_na
# 1139             0          0            0            0           0
# 533              0          0            0            0           0
# 459              0          0            0            0           0
# 1150             0          1            0            0           0
# 393              0          0            0            0           0
# ...            ...        ...          ...          ...         ...
# 753              0          0            0            0           0
# 1052             0          1            0            0           0
# 426              0          0            0            0           0
# 554              0          0            0            0           0
# 1213             0          1            0            0           0
#
# [262 rows x 14 columns]

# %% [markdown]
# ### Replace Missing data in categorical variables with the string **Missing**

# %%
for col in vars_cat:
    X_train[col] = X_train[col].fillna('Missing')
    X_test[col] = X_test[col].fillna('Missing')
X_test
# Out:
#       pclass     sex   age  sibsp  parch     fare    cabin embarked title  \
# 1139       3    male  38.0      0      0   7.8958  Missing        S    Mr
# 533        2  female  21.0      0      1  21.0000  Missing        S  Miss
# 459        2    male  42.0      1      0  27.0000  Missing        S    Mr
# 1150       3    male  28.0      0      0  14.5000  Missing        S    Mr
# 393        2    male  25.0      0      0  31.5000  Missing        S    Mr
# ...      ...     ...   ...    ...    ...      ...      ...      ...   ...
# 753        3    male  22.0      0      0   8.0500  Missing        S    Mr
# 1052       3    male  28.0      0      0   7.8958  Missing        S    Mr
# 426        2    male  30.0      0      0  13.0000  Missing        S    Mr
# 554        2    male  26.0      0      0  13.0000  Missing        S    Mr
# 1213       3    male  28.0      0      0   8.0500  Missing        S    Mr
#
#       pclass_is_na  age_is_na  sibsp_is_na  parch_is_na  fare_is_na
# 1139             0          0            0            0           0
# 533              0          0            0            0           0
# 459              0          0            0            0           0
# 1150             0          1            0            0           0
# 393              0          0            0            0           0
# ...            ...        ...          ...          ...         ...
# 753              0          0            0            0           0
# 1052             0          1            0            0           0
# 426              0          0            0            0           0
# 554              0          0            0            0           0
# 1213             0          1            0            0           0
#
# [262 rows x 14 columns]

# %% [markdown]
# ### Remove rare labels in categorical variables
#
# - remove labels present in less than 5 % of the passengers

# %%
def find_rare_category(df, col, rare_perc):
    tmp = df.groupby(col)['age'].count() / len(df)
    return tmp[tmp < rare_perc].index

# %%
for col in vars_cat:
    rare_labels = find_rare_category(X_train, col, 0.05)
    X_train = X_train[~X_train[col].isin(rare_labels)]
    y_train = y_train[X_train.index]
    X_test = X_test[~X_test[col].isin(rare_labels)]
    y_test = y_test[X_test.index]
X_test
# Out:
#       pclass     sex   age  sibsp  parch     fare    cabin embarked title  \
# 1139       3    male  38.0      0      0   7.8958  Missing        S    Mr
# 533        2  female  21.0      0      1  21.0000  Missing        S  Miss
# 459        2    male  42.0      1      0  27.0000  Missing        S    Mr
# 1150       3    male  28.0      0      0  14.5000  Missing        S    Mr
# 393        2    male  25.0      0      0  31.5000  Missing        S    Mr
# ...      ...     ...   ...    ...    ...      ...      ...      ...   ...
# 753        3    male  22.0      0      0   8.0500  Missing        S    Mr
# 1052       3    male  28.0      0      0   7.8958  Missing        S    Mr
# 426        2    male  30.0      0      0  13.0000  Missing        S    Mr
# 554        2    male  26.0      0      0  13.0000  Missing        S    Mr
# 1213       3    male  28.0      0      0   8.0500  Missing        S    Mr
#
#       pclass_is_na  age_is_na  sibsp_is_na  parch_is_na  fare_is_na
# 1139             0          0            0            0           0
# 533              0          0            0            0           0
# 459              0          0            0            0           0
# 1150             0          1            0            0           0
# 393              0          0            0            0           0
# ...            ...        ...          ...          ...         ...
# 753              0          0            0            0           0
# 1052             0          1            0            0           0
# 426              0          0            0            0           0
# 554              0          0            0            0           0
# 1213             0          1            0            0           0
#
# [210 rows x 14 columns]

# %% [markdown]
# ### Perform one hot encoding of categorical variables into k-1 binary variables
#
# - k-1, means that if the variable contains 9 different categories, we create 8 different binary variables
# - Remember to drop the original categorical variable (the one with the strings) after the encoding

# %%
for col in vars_cat:
    X_train = pd.concat([X_train, pd.get_dummies(X_train[col], drop_first=True)], axis=1)
    X_train = X_train.drop([col], axis=1)
    X_test = pd.concat([X_test, pd.get_dummies(X_test[col], drop_first=True)], axis=1)
    X_test = X_test.drop([col], axis=1)
print(X_train.shape, X_test.shape)
X_test
# Out:
# (823, 16) (210, 16)
#       pclass   age  sibsp  parch     fare  pclass_is_na  age_is_na  \
# 1139       3  38.0      0      0   7.8958             0          0
# 533        2  21.0      0      1  21.0000             0          0
# 459        2  42.0      1      0  27.0000             0          0
# 1150       3  28.0      0      0  14.5000             0          1
# 393        2  25.0      0      0  31.5000             0          0
# ...      ...   ...    ...    ...      ...           ...        ...
# 753        3  22.0      0      0   8.0500             0          0
# 1052       3  28.0      0      0   7.8958             0          1
# 426        2  30.0      0      0  13.0000             0          0
# 554        2  26.0      0      0  13.0000             0          0
# 1213       3  28.0      0      0   8.0500             0          1
#
#       sibsp_is_na  parch_is_na  fare_is_na  male  Missing  Q  S  Mr  Mrs
# 1139            0            0           0     1        1  0  1   1    0
# 533             0            0           0     0        1  0  1   0    0
# 459             0            0           0     1        1  0  1   1    0
# 1150            0            0           0     1        1  0  1   1    0
# 393             0            0           0     1        1  0  1   1    0
# ...           ...          ...         ...   ...      ... .. ..  ..  ...
# 753             0            0           0     1        1  0  1   1    0
# 1052            0            0           0     1        1  0  1   1    0
# 426             0            0           0     1        1  0  1   1    0
# 554             0            0           0     1        1  0  1   1    0
# 1213            0            0           0     1        1  0  1   1    0
#
# [210 rows x 16 columns]

# %% [markdown]
# ### Scale the variables
#
# - Use the standard scaler from Scikit-learn

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Train the Logistic Regression model
#
# - Set the regularization parameter to 0.0005
# - Set the seed to 0

# %%
lr = LogisticRegression(C=0.0005, random_state=0)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.0005, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Make predictions and evaluate model performance
#
# Determine:
# - roc-auc
# - accuracy
#
# **Important, remember that to determine the accuracy, you need the outcome 0, 1, referring to survived or not. But to determine the roc-auc you need the probability of survival.**

# %%
preds_proba = lr.predict_proba(X_test)
preds = lr.predict(X_test)
acc = accuracy_score(y_test, preds)
roc_auc = roc_auc_score(y_test, preds_proba[:, 1])
print('Accuracy: {:.2f}%'.format(acc * 100))
print('ROC-AUC: {:.2f}'.format(roc_auc))
# Out:
# Accuracy: 69.05%
# ROC-AUC: 0.76

# %% [markdown]
# That's it! Well done
#
# **Keep this code safe, as we will use this notebook later on, to build production code, in our next assignement!!**
